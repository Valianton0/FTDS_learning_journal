# %% [markdown]
# ### PERKENALAN

# %% [markdown]
# ### IMPORT LIBRARY

# %% [markdown]
# Kita akan mengimport beberapa library berupa :
#
# Numpy dan Sympy untuk memudahkan operasi komputasi tipe data numerik,
#
# Pandas untuk mempermudah dalam mengolah dan menganalisa data-data terstruktur,
#
# Matplotlib untuk visualisasi data, dan
#
# PIL untuk memanipulasi file gambar

# %%
import numpy as np
import sympy as sym
import pandas as pd
import matplotlib.pyplot as plt
import PIL as pil

# %% [markdown]
# #### DATA LOADING

# %% [markdown]
# Pertama-tama kita perlu mengambil gambar untuk kita analisa. Kita dapat menggunakan PIL untuk mengambil data tersebut. Sekaligus juga mengkonversinya ke greyscale untuk mempermudah analisa kedepannya nanti

# %%
from PIL import Image

img = Image.open(r'C:\Users\rezaa\FTDS_HACTIV8\learning_journal\phase_0\graded_challenge\img2.jpg').convert('L')
img.save('greyimg2.png')

# %%
greyimg2 = Image.open(r'C:\Users\rezaa\FTDS_HACTIV8\learning_journal\phase_0\graded_challenge\greyimg2.png')

# %% [markdown]
# ### DATA PROCESSING

# %%
greyimg2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=780x438 at 0x1ED9991D000>

# %% [markdown]
# Pada script ini kita akan mengubah data gambar menjadi data array

# %%
pic = np.array(greyimg2.getdata())

# %%
width, height = greyimg2.size

# %%
x, y = np.meshgrid(range(width), range(height))

coordinate = np.concatenate(
    [greyimg2.getdata(), 
    x.reshape(-1,1), 
    y.reshape(-1,1)], 
    axis=0
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8552/3703629615.py in <module>
#       1 x, y = np.meshgrid(range(width), range(height))
#       2
# ----> 3 coordinate = np.concatenate(
#       4     [greyimg2.getdata(),
#       5     x.reshape(-1,1),
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# ValueError: all the input arrays must have same number of dimensions, but the array at index 0 has 1 dimension(s) and the array at index 1 has 2 dimension(s)

# %% [markdown]
# ### IMAGE PROCESSING

# %% [markdown]
# ### HASIL DAN KESIMPULAN
